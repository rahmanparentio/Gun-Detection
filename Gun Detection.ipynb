# %%
import numpy as np 
import cv2 
import imutils 
import datetime

# %% [markdown]
# ### Realtime Detection

# %% [markdown]
# #### Without Notifications

# %%
gun_cascade = cv2.CascadeClassifier('dataset/cascade.xml') 
camera = cv2.VideoCapture(0)
   
firstFrame = None
gun_exist = False

while True: 
      
    ret, frame = camera.read() 
   
    frame = imutils.resize(frame, width = 500) 
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY) 
       
    gun = gun_cascade.detectMultiScale(gray, 1.3, 5, minSize = (100, 100))
    
    if len(gun) > 3: # Accuracy test by epoch
        gun_exist = True
           
    for (x, y, w, h) in gun: 
          
        frame = cv2.rectangle(frame, 
                              (x, y), 
                              (x + w, y + h), 
                              (0, 0, 255), 2) 
        roi_gray = gray[y:y + h, x:x + w] 
        roi_color = frame[y:y + h, x:x + w]     
   
    if firstFrame is None: 
        firstFrame = gray 
        continue
        
        
    cv2.putText(frame, datetime.datetime.now().strftime("%A %d %B %Y %I:%M:%S %p"), 
                (10, frame.shape[0] - 10), 
                cv2.FONT_HERSHEY_SIMPLEX, 
                0.35, (255, 0, 0), 1) 
   
    cv2.imshow("Test Feed", frame) 
    key = cv2.waitKey(1) & 0xFF
   
    if key == ord('q'): 
        break
    
camera.release() 
cv2.destroyAllWindows()

# %% [markdown]
# #### With Notifications

# %%
gun_cascade = cv2.CascadeClassifier('dataset/cascade.xml') 
camera = cv2.VideoCapture(0)
   
firstFrame = None
gun_exist = False

while True: 
      
    ret, frame = camera.read() 
   
    frame = imutils.resize(frame, width = 500) 
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY) 
       
    gun = gun_cascade.detectMultiScale(gray, 1.3, 5, minSize = (100, 100))
    
    if len(gun) > 2: # Accuracy test by epoch
        gun_exist = True
           
    for (x, y, w, h) in gun: 
        frame = cv2.rectangle(frame, 
                              (x, y), 
                              (x + w, y + h), 
                              (0, 0, 255), 2) 
        roi_gray = gray[y:y + h, x:x + w] 
        roi_color = frame[y:y + h, x:x + w]
   
    if firstFrame is None: 
        firstFrame = gray 
        continue
        
    cv2.putText(frame, datetime.datetime.now().strftime("%A %d %B %Y %I:%M:%S %p"), 
                (10, frame.shape[0] - 10), 
                cv2.FONT_HERSHEY_SIMPLEX, 
                0.35, (255, 0, 0), 1) 
   
    cv2.imshow("Gun Detection Input", frame) 
    key = cv2.waitKey(1) & 0xFF
   
    if gun_exist:
        print("WARNING : GUNS DETECTED") # Notifications
      
    if key == ord('q'): 
        break
    
camera.release() 
cv2.destroyAllWindows()

# %%
#####################################################################

# %%
import numpy as np 
import cv2 
import imutils 
import datetime

# %% [markdown]
# ## Video Detection

# %% [markdown]
# #### Without Notifications

# %%
gun_cascade = cv2.CascadeClassifier('dataset/cascade.xml') 
camera = cv2.VideoCapture("videoplayback.mp4") 
   
firstFrame = None
gun_exist = False

while True: 
      
    ret, frame = camera.read() 
   
    frame = imutils.resize(frame, width = 500) 
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY) 
       
    gun = gun_cascade.detectMultiScale(gray, 1.3, 5, minSize = (100, 100))
    
    if len(gun) > 3: 
        gun_exist = True
           
    for (x, y, w, h) in gun: 
          
        frame = cv2.rectangle(frame, 
                              (x, y), 
                              (x + w, y + h), 
                              (0, 0, 255), 2) 
        roi_gray = gray[y:y + h, x:x + w] 
        roi_color = frame[y:y + h, x:x + w]     
   
    if firstFrame is None: 
        firstFrame = gray 
        continue
        
    cv2.putText(frame, datetime.datetime.now().strftime("%A %d %B %Y %I:%M:%S %p"), 
                (10, frame.shape[0] - 10), 
                cv2.FONT_HERSHEY_SIMPLEX, 
                0.35, (255, 0, 0), 1) 
   
    cv2.imshow("Test Feed", frame)
    key = cv2.waitKey(1) & 0xFF
      
    if key == ord('q'): 
        break
    
camera.release() 
cv2.destroyAllWindows()

# %% [markdown]
# #### With Notifications

# %%
gun_cascade = cv2.CascadeClassifier('dataset/cascade.xml') 
camera = cv2.VideoCapture("videoplayback.mp4") 
   
firstFrame = None
gun_exist = False

while True: 
      
    ret, frame = camera.read() 
   
    frame = imutils.resize(frame, width = 500) 
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY) 
       
    gun = gun_cascade.detectMultiScale(gray, 1.3, 5, minSize = (100, 100))
    
    if len(gun) > 3: 
        gun_exist = True
           
    for (x, y, w, h) in gun: 
          
        frame = cv2.rectangle(frame, 
                              (x, y), 
                              (x + w, y + h), 
                              (0, 0, 255), 2) 
        roi_gray = gray[y:y + h, x:x + w] 
        roi_color = frame[y:y + h, x:x + w]     
   
    if firstFrame is None: 
        firstFrame = gray 
        continue
        
        
    cv2.putText(frame, datetime.datetime.now().strftime("%A %d %B %Y %I:%M:%S %p"), 
                (10, frame.shape[0] - 10), 
                cv2.FONT_HERSHEY_SIMPLEX, 
                0.35, (255, 0, 0), 1) 
   
    cv2.imshow("Test Feed", frame)
    key = cv2.waitKey(1) & 0xFF
    
    if gun_exist:
        print("WARNING : GUNS DETECTED")
      
    if key == ord('q'): 
        break
    
camera.release() 
cv2.destroyAllWindows()
# Out:
# WARNING : GUNS DETECTED
# WARNING : GUNS DETECTED
# WARNING : GUNS DETECTED
# WARNING : GUNS DETECTED
# WARNING : GUNS DETECTED
# WARNING : GUNS DETECTED
# WARNING : GUNS DETECTED
# WARNING : GUNS DETECTED
# WARNING : GUNS DETECTED
# WARNING : GUNS DETECTED
# WARNING : GUNS DETECTED
# WARNING : GUNS DETECTED
# WARNING : GUNS DETECTED
# WARNING : GUNS DETECTED
# WARNING : GUNS DETECTED
# WARNING : GUNS DETECTED
# WARNING : GUNS DETECTED
# WARNING : GUNS DETECTED
# WARNING : GUNS DETECTED
# WARNING : GUNS DETECTED
# WARNING : GUNS DETECTED
# WARNING : GUNS DETECTED
# WARNING : GUNS DETECTED
# WARNING : GUNS DETECTED
# WARNING : GUNS DETECTED
# WARNING : GUNS DETECTED
# WARNING : GUNS DETECTED
# WARNING : GUNS DETECTED
# WARNING : GUNS DETECTED
# WARNING : GUNS DETECTED
# WARNING : GUNS DETECTED
# WARNING : GUNS DETECTED
# WARNING : GUNS DETECTED
# WARNING : GUNS DETECTED
# WARNING : GUNS DETECTED
# WARNING : GUNS DETECTED
# WARNING : GUNS DETECTED
# WARNING : GUNS DETECTED
# ...

# %%
########################### BUAT TEST ############################

# %%
import numpy as np 
import cv2 
import imutils 
import datetime

# %%
gun_cascade = cv2.CascadeClassifier('dataset/cascade.xml') 
camera = cv2.VideoCapture("videoplayback.mp4")
   
firstFrame = None
gun_exist = False

while True: 
      
    ret, frame = camera.read() 
   
    frame = imutils.resize(frame, width = 500) 
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY) 
       
    gun = gun_cascade.detectMultiScale(gray, 1.3, 5, minSize = (100, 100))
    
    if len(gun) > 2.5: # Accuracy test by epoch
        gun_exist = True
           
    for (x, y, w, h) in gun: 
        frame = cv2.rectangle(frame, 
                              (x, y), 
                              (x + w, y + h), 
                              (0, 0, 255), 2) 
        roi_gray = gray[y:y + h, x:x + w] 
        roi_color = frame[y:y + h, x:x + w]
   
    if firstFrame is None: 
        firstFrame = gray 
        continue
        
    cv2.putText(frame, datetime.datetime.now().strftime("%A %d %B %Y %I:%M:%S %p"), 
                (10, frame.shape[0] - 10), 
                cv2.FONT_HERSHEY_SIMPLEX, 
                0.35, (255, 0, 0), 1) 
   
    cv2.imshow("Gun Detection Input", frame) 
    key = cv2.waitKey(1) & 0xFF
   
    if gun_exist:
        print("WARNING : GUNS DETECTED") # Notifications
      
    if key == ord('q'): 
        break
    
camera.release() 
cv2.destroyAllWindows()
